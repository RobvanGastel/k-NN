# %%
import numpy as np

# %%
minkowski = np.loadtxt('../results/minkowski_small_train_LOOCV.txt', delimiter=',', skiprows=1)

# %%
minkowski
# Out:
# array([[219.,   1.,   1.],
#        [219.,   2.,   1.],
#        [184.,   3.,   1.],
#        [203.,   4.,   1.],
#        [207.,   5.,   1.],
#        [208.,   6.,   1.],
#        [221.,   7.,   1.],
#        [221.,   8.,   1.],
#        [230.,   9.,   1.],
#        [224.,  10.,   1.],
#        [228.,  11.,   1.],
#        [229.,  12.,   1.],
#        [239.,  13.,   1.],
#        [236.,  14.,   1.],
#        [247.,  15.,   1.],
#        [247.,  16.,   1.],
#        [263.,  17.,   1.],
#        [260.,  18.,   1.],
#        [263.,  19.,   1.],
#        [274.,  20.,   1.],
#        [219.,   1.,   2.],
#        [219.,   2.,   2.],
#        [184.,   3.,   2.],
#        [203.,   4.,   2.],
#        [207.,   5.,   2.],
#        [208.,   6.,   2.],
#        [221.,   7.,   2.],
#        [221.,   8.,   2.],
#        [230.,   9.,   2.],
#        [224.,  10.,   2.],
#        [228.,  11.,   2.],
#        [229.,  12.,   2.],
#        [239.,  13.,   2.],
#        [236.,  14.,   2.],
# ...

# %%
min(minkowski[::,0])
# Out:
# 184.0

# %%
print("index [loss, k, p]")
for i, val in enumerate(minkowski):
    if val[0] == min(minkowski[::,0]):
        print(i, val)
# Out:
# index [loss, k, p]
# 2 [184.   3.   1.]
# 22 [184.   3.   2.]
# 42 [184.   3.   3.]
# 62 [184.   3.   4.]
# 82 [184.   3.   5.]
# 102 [184.   3.   6.]
# 122 [184.   3.   7.]
# 142 [184.   3.   8.]
# 162 [184.   3.   9.]
# 182 [184.   3.  10.]
# 202 [184.   3.  11.]
# 222 [184.   3.  12.]
# 242 [184.   3.  13.]
# 262 [184.   3.  14.]
# 282 [184.   3.  15.]
